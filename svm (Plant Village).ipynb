# %%
import numpy as np

dataset = np.load("PlantVillage.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel='rbf')

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
print(f"Test Accuracy: {accuracy_score(y_pred, y_test)*100}%")
# Out:
# Test Accuracy: 88.78571428571429%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.92      0.96      0.94       318
#   early_blight       0.80      0.61      0.69       200
#    late_blight       0.86      0.88      0.87       382
# bacterial_spot       0.90      0.96      0.93       425
#   mosaic_virus       0.95      0.92      0.93        75
#
#       accuracy                           0.89      1400
#      macro avg       0.89      0.87      0.87      1400
#   weighted avg       0.88      0.89      0.88      1400

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()
