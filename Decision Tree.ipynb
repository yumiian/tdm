# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Plant Village

# %% [markdown]
# ## Load Dataset

# %%
import numpy as np

dataset = np.load("/content/drive/MyDrive/Data Mining/Project/PlantVillage.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ## Model Training

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier

# %%
model = DecisionTreeClassifier(criterion="entropy", max_depth=10, min_samples_split=10, min_samples_leaf=2, max_features="sqrt", class_weight="balanced", random_state=13)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=10, max_features='sqrt', min_samples_leaf=2,
#                        min_samples_split=10, random_state=13)

# %% [markdown]
# # Model Evaluation

# %%
# Predict on the training data
y_train_pred = model.predict(X_train)

# Calculate and print the train accuracy
train_accuracy = accuracy_score(y_train, y_train_pred) * 100
print(f"Train Accuracy: {train_accuracy}%")

y_pred = model.predict(X_test)

# Evaluate the model accuracy
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Train Accuracy: 86.05357142857143%
# Test Accuracy: 62.642857142857146%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.64      0.66      0.65       318
#   early_blight       0.42      0.44      0.43       200
#    late_blight       0.67      0.60      0.64       382
# bacterial_spot       0.71      0.74      0.73       425
#   mosaic_virus       0.44      0.48      0.46        75
#
#       accuracy                           0.63      1400
#      macro avg       0.58      0.58      0.58      1400
#   weighted avg       0.63      0.63      0.63      1400

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()

# %% [markdown]
# # Plant Doc

# %% [markdown]
# ## Load Dataset

# %%
import numpy as np

dataset = np.load("/content/drive/MyDrive/Data Mining/Project/PlantDoc_v3.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ## Model Training

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier

# %%
model = DecisionTreeClassifier(max_depth=20, min_samples_leaf=1, min_samples_split=3, max_features='sqrt', criterion='entropy',  random_state=13)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        min_samples_split=3, random_state=13)

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on the training data
y_train_pred = model.predict(X_train)

# Calculate and print the train accuracy
train_accuracy = accuracy_score(y_train, y_train_pred) * 100
print(f"Train Accuracy: {train_accuracy}%")

y_pred = model.predict(X_test)

# Evaluate the model accuracy
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Train Accuracy: 97.80159384446276%
# Test Accuracy: 27.424242424242422%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.28      0.25      0.27       162
#   early_blight       0.25      0.25      0.25       114
#    late_blight       0.26      0.38      0.31        84
# bacterial_spot       0.13      0.18      0.15        84
#   mosaic_virus       0.40      0.30      0.34       216
#
#       accuracy                           0.27       660
#      macro avg       0.26      0.27      0.26       660
#   weighted avg       0.29      0.27      0.28       660

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()
