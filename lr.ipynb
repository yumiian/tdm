# %% [markdown]
# # Logistic Regression (LR)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## PlantVillage

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantVillage.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Test Accuracy: 72.92857142857143%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.81      0.79      0.80       318
#   early_blight       0.52      0.41      0.46       200
#    late_blight       0.68      0.69      0.69       382
# bacterial_spot       0.75      0.84      0.79       425
#   mosaic_virus       0.93      0.92      0.93        75
#
#       accuracy                           0.73      1400
#      macro avg       0.74      0.73      0.73      1400
#   weighted avg       0.72      0.73      0.72      1400

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()

# %% [markdown]
# ## PlantDoc

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantDoc_v3.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# c:\Users\yeexh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Test Accuracy: 34.39393939393939%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.35      0.65      0.45       162
#   early_blight       0.39      0.30      0.34       114
#    late_blight       0.40      0.48      0.43        84
# bacterial_spot       0.13      0.12      0.12        84
#   mosaic_virus       0.42      0.17      0.24       216
#
#       accuracy                           0.34       660
#      macro avg       0.34      0.34      0.32       660
#   weighted avg       0.36      0.34      0.32       660

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))  
disp.plot(ax=ax)
plt.tight_layout()
