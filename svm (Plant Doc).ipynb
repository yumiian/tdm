# %%
import numpy as np

dataset = np.load("PlantDoc_v3.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel='rbf')

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
print(f"Test Accuracy: {accuracy_score(y_pred, y_test)*100}%")
# Out:
# Test Accuracy: 34.24242424242424%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.28      0.51      0.37       162
#   early_blight       0.50      0.49      0.50       114
#    late_blight       0.48      0.39      0.43        84
# bacterial_spot       0.18      0.12      0.14        84
#   mosaic_virus       0.34      0.20      0.25       216
#
#       accuracy                           0.34       660
#      macro avg       0.36      0.34      0.34       660
#   weighted avg       0.35      0.34      0.33       660

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()
