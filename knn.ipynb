# %% [markdown]
# # K-Nearest Neighbor (KNN)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## PlantVillage

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantVillage.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=2, p=1)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2, p=1)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_pred, y_test)*100}%")
# Out:
# Test Accuracy: 70.0%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.77      0.67      0.72       318
#   early_blight       0.65      0.39      0.49       200
#    late_blight       0.66      0.73      0.70       382
# bacterial_spot       0.70      0.91      0.79       425
#   mosaic_virus       0.86      0.32      0.47        75
#
#       accuracy                           0.70      1400
#      macro avg       0.73      0.60      0.63      1400
#   weighted avg       0.71      0.70      0.69      1400

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()

# %% [markdown]
# ## PlantDoc

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantDoc_v3.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=2, n_jobs=1)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=1, n_neighbors=2)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_pred, y_test)*100}%")
# Out:
# Test Accuracy: 22.272727272727273%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.23      0.40      0.29       162
#   early_blight       0.24      0.30      0.26       114
#    late_blight       0.24      0.21      0.23        84
# bacterial_spot       0.17      0.11      0.13        84
#   mosaic_virus       0.20      0.10      0.13       216
#
#       accuracy                           0.22       660
#      macro avg       0.22      0.22      0.21       660
#   weighted avg       0.22      0.22      0.21       660

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()
