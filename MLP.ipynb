# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## PlantVillage

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantVillage.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.neural_network import MLPClassifier as mlp

# %%
model = mlp(max_iter=300).fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Test Accuracy: 71.78571428571429%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.81      0.89      0.84       318
#   early_blight       0.42      0.62      0.50       200
#    late_blight       0.79      0.65      0.72       382
# bacterial_spot       0.78      0.73      0.75       425
#   mosaic_virus       0.98      0.53      0.69        75
#
#       accuracy                           0.72      1400
#      macro avg       0.75      0.68      0.70      1400
#   weighted avg       0.75      0.72      0.72      1400

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()

# %% [markdown]
# ## PlantDoc

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantDoc_v3.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.neural_network import MLPClassifier as mlp

# %%
model = mlp(random_state=1, max_iter=300).fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Test Accuracy: 24.393939393939394%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.28      0.29      0.29       162
#   early_blight       0.53      0.15      0.23       114
#    late_blight       0.62      0.37      0.46        84
# bacterial_spot       0.10      0.43      0.17        84
#   mosaic_virus       0.43      0.14      0.21       216
#
#       accuracy                           0.24       660
#      macro avg       0.39      0.28      0.27       660
#   weighted avg       0.39      0.24      0.26       660

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))  
disp.plot(ax=ax)
plt.tight_layout()
