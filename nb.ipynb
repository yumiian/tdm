# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## PlantVillage

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantVillage.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Test Accuracy: 62.92857142857143%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.58      0.81      0.67       318
#   early_blight       0.47      0.52      0.49       200
#    late_blight       0.69      0.37      0.48       382
# bacterial_spot       0.81      0.76      0.78       425
#   mosaic_virus       0.43      0.76      0.55        75
#
#       accuracy                           0.63      1400
#      macro avg       0.60      0.64      0.60      1400
#   weighted avg       0.66      0.63      0.62      1400

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)
plt.tight_layout()

# %% [markdown]
# ## PlantDoc

# %% [markdown]
# ### Load Dataset

# %%
import numpy as np

dataset = np.load("PlantDoc_v3.npz")

X_train = dataset["X_train"]
X_test = dataset["X_test"]
y_train = dataset["y_train"]
y_test = dataset["y_test"]

# %% [markdown]
# ### Model Training

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Model Evaluation

# %%
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Test Accuracy: 38.93939393939394%

# %%
classes = ["healthy", "early_blight", "late_blight", "bacterial_spot", "mosaic_virus"]
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#        healthy       0.44      0.43      0.44       162
#   early_blight       0.59      0.32      0.42       114
#    late_blight       0.22      0.49      0.31        84
# bacterial_spot       0.43      0.07      0.12        84
#   mosaic_virus       0.43      0.48      0.45       216
#
#       accuracy                           0.39       660
#      macro avg       0.42      0.36      0.35       660
#   weighted avg       0.43      0.39      0.38       660

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))  
disp.plot(ax=ax)
plt.tight_layout()
